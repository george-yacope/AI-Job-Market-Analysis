# %% [markdown]
# # AI Job Market Analysis

# %% [markdown]
# ## 1. Imports & Configuration

# %%
# --- 1. Core Libraries ---
import pandas as pd
import numpy as np
import os, json
import warnings

# --- 2. Visualization Libraries ---
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.io as pio
pio.renderers.default = "notebook_connected"

# --- 3. Scikit-Learn ---
from sklearn.preprocessing import MultiLabelBinarizer

# --- 4. Configuration ---
pio.renderers.default = "notebook_connected"
warnings.filterwarnings('ignore') # Suppress warnings for cleaner output
sns.set_style('whitegrid')

# --- 5. Global Aesthetics ---
# Define a consistent color palette
palette = ['#023047', '#219ebc', '#ffb703', '#8ecae6', '#fb8500']

# Apply to libraries
sns.set_palette(palette)
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=palette)
px.defaults.template = "plotly_white"
px.defaults.color_discrete_sequence = palette

print("Setup Complete. Libraries loaded and palette applied.")
# Out:
# Setup Complete. Libraries loaded and palette applied.

# %% [markdown]
# ## 2. Helper Functions

# %%
# --- A. Data Helpers ---

def get_counts(df, col, top_n=None):
    """Calculates frequency and percentage, optionally returning top N."""
    counts = df[col].value_counts().reset_index()
    counts.columns = [col, 'count']
    if top_n:
        counts = counts.head(top_n)
    counts['percent'] = (counts['count'] / counts['count'].sum() * 100).round(1)
    return counts

def get_time_trend(df, date_col, freq='M'):
    """Aggregates data by time (M=Month, Q=Quarter, Y=Year)."""
    temp_df = df.copy()
    temp_df[date_col] = pd.to_datetime(temp_df[date_col])
    trend = temp_df.set_index(date_col).resample(freq).size().reset_index(name='count')
    return trend

# --- B. Plotting Functions ---

def plot_bar_chart(df, col, title, top_n=15, orientation='v', color=None):
    """Plots a standard Bar Chart with percentages."""
    data = get_counts(df, col, top_n)
    if orientation == 'h':
        x_val, y_val = 'count', col
        data = data.sort_values('count', ascending=True)
    else:
        x_val, y_val = col, 'count'
        
    fig = px.bar(data, x=x_val, y=y_val, title=title, text='percent',
                 color=color, orientation=orientation)
    fig.update_traces(texttemplate='%{text:.1f}%', textposition='outside')
    fig.update_layout(showlegend=False, height=600)
    return fig

def plot_pie_chart(df, col, title):
    """Plots a Donut Chart for categorical distributions."""
    data = get_counts(df, col)
    fig = px.pie(data, names=col, values='count', title=title, hole=0.4,
                 color_discrete_sequence=palette)
    fig.update_traces(textposition='inside', textinfo='percent+label')
    return fig

def plot_distribution(df, col, title, nbins=40):
    """Plots a Histogram with a marginal Box Plot."""
    fig = px.histogram(df, x=col, nbins=nbins, title=title, marginal="box",
                       color_discrete_sequence=[palette[0]])
    fig.update_layout(bargap=0.1)
    return fig

def plot_box_comparison(df, cat_col, num_col, title, color=None):
    """Plots a Box Plot comparing numerical distributions across categories."""
    order = df.groupby(cat_col)[num_col].median().sort_values().index
    fig = px.box(df, x=cat_col, y=num_col, title=title, color=color,
                 category_orders={cat_col: order})
    return fig

def plot_heatmap(df, x_col, y_col, title):
    """Plots a Heatmap to show density/frequency between two variables."""
    pivot_table = pd.crosstab(df[y_col], df[x_col])
    fig = px.imshow(pivot_table, title=title, aspect='auto',
                    labels=dict(x=x_col, y=y_col, color="Count"))
    return fig

def plot_outlier_analysis(df, col, title="Outlier Analysis (Box + Hist)"):
    """Creates a combined Box and Histogram plot for detailed outlier analysis."""
    s = df[col].dropna()
    fig = make_subplots(rows=2, cols=1, shared_xaxes=True, 
                        row_heights=[0.3, 0.7], vertical_spacing=0.05,
                        specs=[[{"type": "box"}], [{"type": "xy"}]])
    
    fig.add_trace(go.Box(x=s, name='Box Plot', marker_color=palette[0], boxpoints='outliers'), row=1, col=1)
    fig.add_trace(go.Histogram(x=s, nbinsx=50, name='Distribution', marker_color=palette[1]), row=2, col=1)
    
    mean_val = s.mean()
    median_val = s.median()
    fig.add_vline(x=mean_val, line_dash='dash', line_color=palette[4], annotation_text=f'Mean: {mean_val:,.0f}')
    fig.add_vline(x=median_val, line_dash='dot', line_color=palette[2], annotation_text=f'Median: {median_val:,.0f}', annotation_position='top left')
    fig.update_layout(title=title, height=700, showlegend=False)
    return fig

def plot_grouped_histogram(df, x_col, group_col, title, top_n=10):
    """Plots a grouped histogram to compare categories."""
    top_items = df[x_col].value_counts().head(top_n).index
    filtered_df = df[df[x_col].isin(top_items)]
    fig = px.histogram(filtered_df, x=x_col, color=group_col, barmode='group',
                       title=title, color_discrete_sequence=palette)
    fig.update_layout(xaxis_tickangle=-45, yaxis_title="Count", height=600)
    return fig

def plot_grouped_box(df, x_col, y_col, group_col, title, top_n=10):
    """Plots a grouped box plot to compare distributions across subgroups."""
    top_items = df[x_col].value_counts().head(top_n).index
    filtered_df = df[df[x_col].isin(top_items)]
    fig = px.box(filtered_df, x=x_col, y=y_col, color=group_col,
                 title=title, color_discrete_sequence=palette)
    fig.update_layout(xaxis_tickangle=-45, height=600)
    return fig

def plot_choropleth_map(df, loc_col, title):
    """Plots a global choropleth map for job distribution."""
    country_counts = df[loc_col].value_counts().reset_index()
    country_counts.columns = ['country', 'count']
    fig = px.choropleth(country_counts, locations="country", locationmode="country names",
                        color="count", hover_name="country",
                        title=title)
    fig.update_layout(geo=dict(showframe=False, showcoastlines=True, projection_type='natural earth'), height=600)
    return fig

def plot_trend(df, x_col, y_col, title, agg_func='count'):
    if agg_func == 'count':
        data = df[x_col].value_counts().reset_index()
        data.columns = [x_col, 'value']
        y_label = 'Number of Jobs'
    else:
        data = df.groupby(x_col)[y_col].mean().reset_index()
        data.columns = [x_col, 'value']
        y_label = 'Avg Salary'


    fig = px.bar(data, x=x_col, y='value', 
                 title=title, text_auto='.2s',
                 color=x_col, 
                 category_orders=orders_dict)
    
    fig.update_layout(xaxis_title=x_col, yaxis_title=y_label, showlegend=False)
    return fig

def plot_time_trend(df, x_col, y_col, title, agg_func='count'):
    """Helper to plot time trends respecting chronological order."""
    if agg_func == 'count':
        data = df[x_col].value_counts().reset_index()
        data.columns = [x_col, 'value']
        y_label = 'Number of Jobs'
    else:
        data = df.groupby(x_col)[y_col].mean().reset_index()
        data.columns = [x_col, 'value']
        y_label = 'Avg Salary'
    data = data.sort_values('value', ascending=False)
    fig = px.bar(data, x=x_col, y='value', title=title, text_auto='.2s')
    fig.update_layout(xaxis_title=x_col, yaxis_title=y_label)
    return fig

# %% [markdown]
# ## 3. Data Loading & Explore

# %%
# Load Data
df = pd.read_csv('data/raw_ai_job_market.csv')

# Basic Inspection
print(f"Dataset Shape: {df.shape}")
df.head()
# Out:
# Dataset Shape: (2000, 12)
#    job_id              company_name    industry                 job_title  \
# 0       1           Foster and Sons  Healthcare              Data Analyst
# 1       2   Boyd, Myers and Ramirez        Tech  Computer Vision Engineer
# 2       3                  King Inc        Tech          Quant Researcher
# 3       4  Cooper, Archer and Lynch        Tech        AI Product Manager
# 4       5                  Hall LLC     Finance            Data Scientist
#
#                                      skills_required experience_level  \
# 0  NumPy, Reinforcement Learning, PyTorch, Scikit...              Mid
# 1                    Scikit-learn, CUDA, SQL, Pandas           Senior
# 2          MLflow, FastAPI, Azure, PyTorch, SQL, GCP            Entry
# 3       Scikit-learn, C++, Pandas, LangChain, AWS, R              Mid
# 4                    Excel, Keras, SQL, Hugging Face           Senior
#
#   employment_type               location salary_range_usd posted_date  \
# 0       Full-time          Tracybury, AR     92860-109598  2025-08-20
# 1       Full-time         Lake Scott, CU     78523-144875  2024-03-22
# 2       Full-time         East Paige, CM    124496-217204  2025-09-18
# 3       Full-time          Perezview, FI     50908-123743  2024-05-08
# 4        Contract  North Desireeland, NE     98694-135413  2025-02-24
#
#   company_size                  tools_preferred
# 0        Large                  KDB+, LangChain
# 1        Large        FastAPI, KDB+, TensorFlow
# 2        Large  BigQuery, PyTorch, Scikit-learn
# 3        Large     TensorFlow, BigQuery, MLflow
# 4        Large               PyTorch, LangChain

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   job_id            2000 non-null   int64
#  1   company_name      2000 non-null   object
#  2   industry          2000 non-null   object
#  3   job_title         2000 non-null   object
#  4   skills_required   2000 non-null   object
#  5   experience_level  2000 non-null   object
#  6   employment_type   2000 non-null   object
#  7   location          2000 non-null   object
#  8   salary_range_usd  2000 non-null   object
#  9   posted_date       2000 non-null   object
#  10  company_size      2000 non-null   object
#  11  tools_preferred   2000 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 187.6+ KB

# %%
df.describe(include=[object]).T
# Out:
#                  count unique                   top freq
# company_name      2000   1909           Johnson LLC    4
# industry          2000      7            Automotive  300
# job_title         2000      8          Data Analyst  271
# skills_required   2000   1985  Power BI, C++, NumPy    2
# experience_level  2000      3                 Entry  702
# employment_type   2000      4            Internship  574
# location          2000   2000         Tracybury, AR    1
# salary_range_usd  2000   2000          92860-109598    1
# posted_date       2000    680            2023-10-03   10
# company_size      2000      3               Startup  672
# tools_preferred   2000    352                  KDB+   96

# %%
cols_to_print = ['industry', 'job_title', 'experience_level', 'employment_type', 'company_size']

for col in cols_to_print:
    print(f"\n=== Unique values for: {col} ===")
    unique_vals = df[col].unique()
    print(unique_vals)
# Out:
# === Unique values for: industry ===
# ['Healthcare' 'Tech' 'Finance' 'E-commerce' 'Automotive' 'Education'
#  'Retail']
#
# === Unique values for: job_title ===
# ['Data Analyst' 'Computer Vision Engineer' 'Quant Researcher'
#  'AI Product Manager' 'Data Scientist' 'ML Engineer' 'NLP Engineer'
#  'AI Researcher']
#
# === Unique values for: experience_level ===
# ['Mid' 'Senior' 'Entry']
#
# === Unique values for: employment_type ===
# ['Full-time' 'Contract' 'Remote' 'Internship']
#
# === Unique values for: company_size ===
# ['Large' 'Startup' 'Mid']

# %%
df.isna().sum()
# Out:
# job_id              0
# company_name        0
# industry            0
# job_title           0
# skills_required     0
# experience_level    0
# employment_type     0
# location            0
# salary_range_usd    0
# posted_date         0
# company_size        0
# tools_preferred     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 4.Data Preprocessing & Engineering

# %% [markdown]
# ### 4.1 Basic Cleaning

# %%
df = df.drop(columns=['job_id'])

# %% [markdown]
# ### 4.2 Feature Engineering: Location (City/Country)

# %%
df[['city', 'country_code']] = df['location'].str.split(',', n=1, expand=True).apply(lambda x: x.str.strip())
df = df.drop(columns=['location'])


with open('data/state_map.json', 'r') as f:
    location_map = json.load(f)

df['country_code'] = df['country_code'].apply(lambda x: x.split(', ')[-1] if ',' in x else x)
# Map it using the JSON
df['country'] = df['country_code'].map(location_map).fillna(df['country_code'])
df = df.drop(columns=['country_code'])

# %% [markdown]
# ### 4.3 Feature Engineering: Salary Parsing

# %%
df[['min_salary', 'max_salary']] = df['salary_range_usd'].str.split('-', n=1, expand=True).astype(float)

df['avg_salary'] = (df['min_salary'] + df['max_salary']) / 2

df = df.drop(columns=['salary_range_usd'])

# %% [markdown]
# ### 4.4 Feature Engineering: Date & Time

# %%
df['posted_date'] = pd.to_datetime(df['posted_date'])
df['year'] = df['posted_date'].dt.year
df['month'] = df['posted_date'].dt.month_name()
df['day_name'] = df['posted_date'].dt.day_name()
df['quarter'] = 'Q' + df['posted_date'].dt.quarter.astype(str)

# %% [markdown]
# ### 4.5 Feature Engineering: Skills (One-Hot Encoding)

# %%
df['skills'] = df[['skills_required', 'tools_preferred']].apply(lambda x: [s.strip() for s in (x['skills_required'] + ',' + x['tools_preferred']).split(',') if s.strip()], axis=1)

mlb = MultiLabelBinarizer()
skills_encoded = mlb.fit_transform(df['skills'])

skills_df = pd.DataFrame(skills_encoded, columns=mlb.classes_, index=df.index)

df = pd.concat([df, skills_df], axis=1)

df.drop(columns=['skills_required', 'tools_preferred', 'skills'], inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 40 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   company_name            2000 non-null   object
#  1   industry                2000 non-null   object
#  2   job_title               2000 non-null   object
#  3   experience_level        2000 non-null   object
#  4   employment_type         2000 non-null   object
#  5   posted_date             2000 non-null   datetime64[ns]
#  6   company_size            2000 non-null   object
#  7   city                    2000 non-null   object
#  8   country                 2000 non-null   object
#  9   min_salary              2000 non-null   float64
#  10  max_salary              2000 non-null   float64
#  11  avg_salary              2000 non-null   float64
#  12  year                    2000 non-null   int32
#  13  month                   2000 non-null   object
#  14  day_name                2000 non-null   object
#  15  quarter                 2000 non-null   object
#  16  AWS                     2000 non-null   int32
#  17  Azure                   2000 non-null   int32
#  18  BigQuery                2000 non-null   int32
#  19  C++                     2000 non-null   int32
#  20  CUDA                    2000 non-null   int32
#  21  Excel                   2000 non-null   int32
#  22  FastAPI                 2000 non-null   int32
#  23  Flask                   2000 non-null   int32
#  24  GCP                     2000 non-null   int32
#  25  Hugging Face            2000 non-null   int32
#  26  KDB+                    2000 non-null   int32
#  27  Keras                   2000 non-null   int32
#  28  LangChain               2000 non-null   int32
#  29  MLflow                  2000 non-null   int32
#  30  NumPy                   2000 non-null   int32
#  31  Pandas                  2000 non-null   int32
#  32  Power BI                2000 non-null   int32
#  33  PyTorch                 2000 non-null   int32
#  34  Python                  2000 non-null   int32
#  35  R                       2000 non-null   int32
#  36  Reinforcement Learning  2000 non-null   int32
#  37  SQL                     2000 non-null   int32
#  38  Scikit-learn            2000 non-null   int32
#  39  TensorFlow              2000 non-null   int32
# dtypes: datetime64[ns](1), float64(3), int32(25), object(11)
# memory usage: 429.8+ KB

# %% [markdown]
# ## 5. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### 5.1 Market Overview

# %%
# 1. Who is hiring the most?
plot_bar_chart(df, 'company_name', '1. Who is hiring the most?', top_n=10).show()

# 2. What are the most common roles? (Using Grouped Histogram as requested)
plot_grouped_histogram(df, 'job_title', 'experience_level', '2. What are the most common roles? (by Experience)').show()

# 3. Which industries are dominating?
plot_bar_chart(df, 'industry', '3. Which industries are dominating?', top_n=10).show()

# 4. Which employment types are dominating?
plot_pie_chart(df, 'employment_type', '4. Which employment types are dominating?').show()

# 5. Which company sizes are dominating?
plot_pie_chart(df, 'company_size', '5. Which company sizes are dominating?').show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="89446a52-ec2c-440e-b8cf-fefe1a7fe5d7" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("89446a52-ec2c-440e-b8cf-fefe1a7fe5d7")) {                    Plotly.newPlot(                        "89446a52-ec2c-440e-b8cf-fefe1a7fe5d7",                        [{"alignmentgroup":"True","hovertemplate":"company_name=%{x}\u003cbr\u003ecount=%{y}\u003cbr\u003epercent=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#023047","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[12.9,9.7,9.7,9.7,9.7,9.7,9.7,9.7,9.7,9.7],"textposition":"outside","x":["Johnson LLC","Smith Inc","Taylor PLC","Anderson PLC","Martin and Sons","Lee Group","Sanchez Ltd","Williams Ltd","Johnson Inc","Jones and Sons"],"xaxis":"x","y":[4,3,3,3,3,3,3,3,3,3],"yaxis":"y","type":"bar","texttemplate":"%{text:.1f}%"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type": ...
# <div>                            <div id="01648aa4-bc6c-4d21-90eb-c350832b127b" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01648aa4-bc6c-4d21-90eb-c350832b127b")) {                    Plotly.newPlot(                        "01648aa4-bc6c-4d21-90eb-c350832b127b",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"experience_level=Mid\u003cbr\u003ejob_title=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mid","marker":{"color":"#023047","pattern":{"shape":""}},"name":"Mid","offsetgroup":"Mid","orientation":"v","showlegend":true,"x":["Data Analyst","AI Product Manager","Data Analyst","NLP Engineer","ML Engineer","NLP Engineer","NLP Engineer","NLP Engineer","Data Analyst","AI Product Manager","Computer Vision Engineer","ML Engineer","NLP Engineer","Quant Researcher","Data Scientist","NLP Engineer","Data Scientist","Quant Researcher","AI Product Manager","Computer Vision Engineer","AI Researcher","Data Analyst","Data Analyst","NLP Engineer","AI Researcher","AI Researcher","NLP Engineer","AI Researcher","Computer Vision Engineer","Quant Researcher","Quant Researcher","NLP Engineer","NLP Engineer","Computer Vision Engineer","Computer Vision Engineer","Computer Vision Engineer","ML Engineer","Quant Researcher","AI Researcher","NLP Engineer","Data Analyst","NLP Engineer","AI Researcher","Quant Researcher","NLP Engineer","Computer Vision Engineer","Quant Researcher","NLP Engineer","NLP Engineer","Computer Vision Engineer","AI Product Manager","ML Engineer","Data Scientist","NLP Engineer","AI Researcher","ML Engineer","AI Product Manager","AI Researcher","NLP Engineer","Quant Researcher","Data Analyst","Quant Researcher","ML Engineer","AI Product Manager","ML Engineer","AI Researcher","AI Product Manager","NLP Engineer","Quant Researcher","AI Product Manager","NLP Engineer","AI Researcher","Computer Vision Engineer","Data Analyst","ML Engineer","Quant Researcher","Quant Researcher","Quant Researcher","Data Analyst","AI Researcher","ML Engineer","AI Researcher","AI Product Manager","AI Product Manager","AI Product Manager","Computer Vision Engineer","Data Scientist","AI Researcher","NLP Engineer","AI Product Manager","Computer Vision Engineer","Data Scientist","Quant Researcher","AI Product Manager","AI Researcher","Computer Vision Engineer","AI Researcher","AI Product Manager","Quant Researcher","Data Analyst","ML Engineer","AI Researcher","Data Analyst","AI Researcher","Data Scientist","Quant Researcher","Data Analyst","AI Product Manager","Computer Vision Engineer","Data Scientist","Data Scientist","AI Researcher","Data Analyst","ML Engineer","AI Product Manager","Data Scientist","AI Product Manager","Quant Researcher","Computer Vision Engineer","Data Analyst","Data Scientist","Computer Vision Engineer","Computer Vision Engineer","ML Engineer","AI Product Manager","AI Product Manager","Computer Vision Engineer","NLP Engineer","AI Researcher","Data Scientist","AI Product Manager","Computer Vision Engineer","NLP Engineer","AI Researcher","Quant Researcher","Quant Researcher","AI Product Manager","ML Engineer","AI Researcher","Data Analyst","AI Researcher","AI Researcher","Computer Vision Engineer","Quant Researcher","Computer Vision Engineer","Computer Vision Engineer","NLP Engineer","Data Analyst","AI Product Manager","ML Engineer","Quant Researcher","Data Scientist","Quant Researcher","NLP Engineer","Data Scientist","Data Scientist","Computer Vision Engineer","ML Engineer","Data Analyst","Computer Vision Engineer","Quant Researcher","AI Researcher","Quant Researcher","Data Analyst","AI Product Manager","Data Scientist","Quant Researcher","Data Scientist","AI Researcher","Computer Vision Engineer","Computer Vision Engineer","AI Pro ...
# <div>                            <div id="cbdd8e6e-dce6-4c3d-b77b-7e3441b0960f" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cbdd8e6e-dce6-4c3d-b77b-7e3441b0960f")) {                    Plotly.newPlot(                        "cbdd8e6e-dce6-4c3d-b77b-7e3441b0960f",                        [{"alignmentgroup":"True","hovertemplate":"industry=%{x}\u003cbr\u003ecount=%{y}\u003cbr\u003epercent=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#023047","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[15.0,14.7,14.6,14.6,14.0,13.7,13.4],"textposition":"outside","x":["Automotive","Education","Retail","E-commerce","Finance","Tech","Healthcare"],"xaxis":"x","y":[300,294,293,291,279,274,269],"yaxis":"y","type":"bar","texttemplate":"%{text:.1f}%"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks" ...
# <div>                            <div id="fe6dfe74-64ab-41ff-a4d9-2088795d400e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe6dfe74-64ab-41ff-a4d9-2088795d400e")) {                    Plotly.newPlot(                        "fe6dfe74-64ab-41ff-a4d9-2088795d400e",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.4,"hovertemplate":"employment_type=%{label}\u003cbr\u003ecount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Internship","Full-time","Contract","Remote"],"legendgroup":"","name":"","showlegend":true,"values":[574,509,465,452],"type":"pie","textinfo":"percent+label","textposition":"inside"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""} ...
# <div>                            <div id="3fd50c80-27e0-42ff-9393-e776ceb37a8e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3fd50c80-27e0-42ff-9393-e776ceb37a8e")) {                    Plotly.newPlot(                        "3fd50c80-27e0-42ff-9393-e776ceb37a8e",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.4,"hovertemplate":"company_size=%{label}\u003cbr\u003ecount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Startup","Mid","Large"],"legendgroup":"","name":"","showlegend":true,"values":[672,671,657],"type":"pie","textinfo":"percent+label","textposition":"inside"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scat ...

# %% [markdown]
# ### 5.2 Salary & Compensation

# %%
# 1. How are salaries distributed?
plot_distribution(df, 'avg_salary', '1. How are salaries distributed?').show()

# 2. Does experience pay off? (Grouped Box: Job Title vs Salary colored by Experience)
plot_grouped_box(df, 'job_title', 'avg_salary', 'experience_level', '2. Does experience pay off? (Salary by Role & Exp)').show()

# 3. Who pays better? (Grouped Box: Company Size vs Salary colored by Experience)
plot_grouped_box(df, 'company_size', 'avg_salary', 'experience_level', '3. Who pays better? (Company Size & Exp)').show()

# 4. Salary vs employment type
plot_box_comparison(df, 'employment_type', 'avg_salary', '4. Salary vs Employment Type', color='employment_type').show()
# Out:
# <div>                            <div id="0f04e3c3-a507-438e-a1dc-48d5da58ca95" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0f04e3c3-a507-438e-a1dc-48d5da58ca95")) {                    Plotly.newPlot(                        "0f04e3c3-a507-438e-a1dc-48d5da58ca95",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"avg_salary=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#023047","pattern":{"shape":""}},"name":"","nbinsx":40,"offsetgroup":"","orientation":"v","showlegend":false,"x":[101229.0,111699.0,170850.0,87325.5,117053.5,136675.0,79584.5,72588.0,161371.5,122195.0,112967.5,98126.5,109898.0,165489.5,173291.5,171267.5,158810.0,165520.5,130295.0,161379.0,148844.5,83849.5,111608.0,96719.0,99766.5,117249.5,60796.5,148691.5,179503.5,116250.0,74513.0,146069.0,80135.5,146755.0,115927.0,122059.5,120173.0,137937.5,111758.5,123785.0,68771.5,136190.0,144976.5,108523.0,114761.0,124381.5,162947.5,152090.5,119857.0,98026.0,182411.5,118823.0,92090.5,95554.5,184756.0,182426.5,89922.5,104503.0,120415.0,89857.5,101113.5,88546.0,135166.0,118081.5,117659.5,152621.0,165377.0,47578.5,161300.0,103727.5,117899.5,80347.5,128014.0,128355.0,171045.5,70476.5,141625.0,59075.0,96143.0,151712.0,138886.0,165480.5,105674.0,100062.0,59119.5,58237.0,132595.5,181715.0,105000.5,149552.0,113658.0,90754.5,149429.5,151115.0,124819.0,115784.5,158743.0,177820.0,152145.0,153026.0,92458.5,123145.5,144737.0,151408.5,153109.5,88147.5,123076.5,144219.0,138258.0,64979.5,80322.5,125919.0,146611.5,90889.0,152503.5,176787.5,112397.5,96385.5,170122.0,72108.0,132648.0,115468.5,115498.0,123185.5,151141.5,121848.5,153136.0,135744.5,177945.0,107496.0,123539.5,71013.0,163805.5,102040.5,157674.0,151506.0,165074.0,161282.0,129108.0,168770.0,85621.5,93267.0,167986.5,87613.5,80851.0,103028.5,108436.5,80304.0,139380.5,119376.0,87502.5,126039.5,117190.0,177701.5,88306.0,169835.5,97376.5,144875.0,89652.5,111709.0,181709.5,55813.5,68090.0,123737.0,133328.5,142264.5,107123.5,60126.5,128378.0,99926.0,133959.5,137107.5,97428.5,122493.0,107572.0,176327.5,120114.5,163893.5,107416.5,117453.5,149154.0,140725.0,119939.0,114837.5,164636.0,141388.5,138735.5,79599.5,79193.5,111749.5,121696.0,155486.0,82727.0,147706.0,155547.0,174884.0,138069.0,145668.5,70078.5,150517.5,160398.0,108857.0,109295.0,197776.5,69148.5,95757.5,119144.5,97635.5,152580.0,134504.0,112227.0,72949.5,90295.0,125136.5,131594.0,163002.0,153083.5,146332.5,82120.0,149394.5,83216.0,181922.0,100901.0,113216.0,106855.0,132844.5,73922.5,165701.0,121662.5,75202.5,101783.5,136174.5,149302.5,157460.0,100537.5,129693.0,127773.5,104121.5,102831.0,82491.5,156088.5,54386.0,79343.0,157281.5,120550.0,124290.0,153865.0,105729.5,187422.5,93502.5,115330.5,67344.5,56274.5,117722.0,179743.5,121384.0,98814.0,83146.0,170858.5,98847.0,78700.5,114860.5,55294.5,75352.5,174978.0,54613.0,95912.5,124210.5,142079.0,129249.0,112582.0,149923.0,170353.0,75601.5,113281.0,117429.5,88078.0,92363.5,130427.5,75276.0,74439.0,145137.5,145166.0,106543.0,128946.0,140656.5,84673.0,91839.0,169983.5,77083.0,192467.0,141768.5,114875.5,159274.5,105374.5,91205.5,148675.0,166853.5,93009.0,131419.5,105064.0,89846.5,88231.0,142402.0,113454.5,75883.0,90819.5,100867.5,125425.0,123220.0,157317.0,102308.5,79767.5,143375.0,61725.0,121919.0,173442.5,73875.0,165588.0,152382.5,138981.5,109009.0,154653.5,120583.5,91011.0,149901.0,155228.0,110313.5,139935.5,187345.5,80437.5,90102.5,146770.0,76979.5,142426.0,150564.0,165633.0,116551.5,100045.5,170571.5,158679.0,88776.0,88446.5,155805.5,129663.5,150750.5,163185.5,90614.0,148805.0,120936.5,94761.5,139482.0,98936.0,110496.0,66503.0,189067.0,125824.0,101885.0,82620.5,158028.0,126876.5,71705.0,146010.0,155828.5,66371.5, ...
# <div>                            <div id="1227bcfb-b8cd-4be2-94a1-0abe7d1daf1a" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1227bcfb-b8cd-4be2-94a1-0abe7d1daf1a")) {                    Plotly.newPlot(                        "1227bcfb-b8cd-4be2-94a1-0abe7d1daf1a",                        [{"alignmentgroup":"True","hovertemplate":"experience_level=Mid\u003cbr\u003ejob_title=%{x}\u003cbr\u003eavg_salary=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mid","marker":{"color":"#023047"},"name":"Mid","notched":false,"offsetgroup":"Mid","orientation":"v","showlegend":true,"x":["Data Analyst","AI Product Manager","Data Analyst","NLP Engineer","ML Engineer","NLP Engineer","NLP Engineer","NLP Engineer","Data Analyst","AI Product Manager","Computer Vision Engineer","ML Engineer","NLP Engineer","Quant Researcher","Data Scientist","NLP Engineer","Data Scientist","Quant Researcher","AI Product Manager","Computer Vision Engineer","AI Researcher","Data Analyst","Data Analyst","NLP Engineer","AI Researcher","AI Researcher","NLP Engineer","AI Researcher","Computer Vision Engineer","Quant Researcher","Quant Researcher","NLP Engineer","NLP Engineer","Computer Vision Engineer","Computer Vision Engineer","Computer Vision Engineer","ML Engineer","Quant Researcher","AI Researcher","NLP Engineer","Data Analyst","NLP Engineer","AI Researcher","Quant Researcher","NLP Engineer","Computer Vision Engineer","Quant Researcher","NLP Engineer","NLP Engineer","Computer Vision Engineer","AI Product Manager","ML Engineer","Data Scientist","NLP Engineer","AI Researcher","ML Engineer","AI Product Manager","AI Researcher","NLP Engineer","Quant Researcher","Data Analyst","Quant Researcher","ML Engineer","AI Product Manager","ML Engineer","AI Researcher","AI Product Manager","NLP Engineer","Quant Researcher","AI Product Manager","NLP Engineer","AI Researcher","Computer Vision Engineer","Data Analyst","ML Engineer","Quant Researcher","Quant Researcher","Quant Researcher","Data Analyst","AI Researcher","ML Engineer","AI Researcher","AI Product Manager","AI Product Manager","AI Product Manager","Computer Vision Engineer","Data Scientist","AI Researcher","NLP Engineer","AI Product Manager","Computer Vision Engineer","Data Scientist","Quant Researcher","AI Product Manager","AI Researcher","Computer Vision Engineer","AI Researcher","AI Product Manager","Quant Researcher","Data Analyst","ML Engineer","AI Researcher","Data Analyst","AI Researcher","Data Scientist","Quant Researcher","Data Analyst","AI Product Manager","Computer Vision Engineer","Data Scientist","Data Scientist","AI Researcher","Data Analyst","ML Engineer","AI Product Manager","Data Scientist","AI Product Manager","Quant Researcher","Computer Vision Engineer","Data Analyst","Data Scientist","Computer Vision Engineer","Computer Vision Engineer","ML Engineer","AI Product Manager","AI Product Manager","Computer Vision Engineer","NLP Engineer","AI Researcher","Data Scientist","AI Product Manager","Computer Vision Engineer","NLP Engineer","AI Researcher","Quant Researcher","Quant Researcher","AI Product Manager","ML Engineer","AI Researcher","Data Analyst","AI Researcher","AI Researcher","Computer Vision Engineer","Quant Researcher","Computer Vision Engineer","Computer Vision Engineer","NLP Engineer","Data Analyst","AI Product Manager","ML Engineer","Quant Researcher","Data Scientist","Quant Researcher","NLP Engineer","Data Scientist","Data Scientist","Computer Vision Engineer","ML Engineer","Data Analyst","Computer Vision Engineer","Quant Researcher","AI Researcher","Quant Researcher","Data Analyst","AI Product Manager","Data Scientist","Quant Researcher","Data Scientist","AI Researcher","Computer Vision Engineer","Computer Vision Engineer","AI Product Manager","NL ...
# <div>                            <div id="a0552dab-9988-48c0-aca0-297a3c8841e6" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a0552dab-9988-48c0-aca0-297a3c8841e6")) {                    Plotly.newPlot(                        "a0552dab-9988-48c0-aca0-297a3c8841e6",                        [{"alignmentgroup":"True","hovertemplate":"experience_level=Mid\u003cbr\u003ecompany_size=%{x}\u003cbr\u003eavg_salary=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mid","marker":{"color":"#023047"},"name":"Mid","notched":false,"offsetgroup":"Mid","orientation":"v","showlegend":true,"x":["Large","Large","Large","Large","Large","Startup","Mid","Mid","Startup","Startup","Startup","Startup","Startup","Mid","Startup","Large","Large","Large","Startup","Large","Large","Mid","Mid","Large","Mid","Startup","Startup","Large","Startup","Large","Mid","Mid","Large","Large","Mid","Mid","Large","Mid","Large","Mid","Startup","Mid","Mid","Large","Startup","Large","Large","Mid","Large","Mid","Large","Startup","Startup","Large","Startup","Mid","Mid","Startup","Mid","Large","Large","Mid","Startup","Large","Mid","Mid","Large","Mid","Mid","Mid","Startup","Large","Large","Mid","Mid","Mid","Mid","Startup","Mid","Large","Mid","Mid","Mid","Mid","Mid","Mid","Mid","Large","Mid","Startup","Startup","Startup","Startup","Startup","Startup","Large","Mid","Mid","Large","Mid","Large","Mid","Large","Mid","Mid","Mid","Startup","Large","Mid","Large","Startup","Startup","Mid","Mid","Startup","Mid","Mid","Mid","Mid","Large","Large","Large","Large","Large","Large","Startup","Large","Large","Mid","Startup","Startup","Startup","Mid","Large","Mid","Startup","Large","Large","Mid","Startup","Startup","Mid","Startup","Startup","Large","Mid","Startup","Startup","Large","Large","Large","Startup","Large","Startup","Startup","Mid","Large","Large","Startup","Startup","Large","Large","Mid","Mid","Startup","Large","Large","Large","Large","Large","Mid","Large","Large","Startup","Large","Large","Mid","Startup","Mid","Large","Mid","Startup","Large","Mid","Large","Mid","Startup","Startup","Mid","Mid","Mid","Startup","Mid","Large","Large","Mid","Startup","Mid","Large","Large","Mid","Startup","Large","Startup","Large","Mid","Large","Startup","Startup","Mid","Startup","Startup","Large","Large","Startup","Mid","Large","Mid","Mid","Large","Startup","Startup","Mid","Large","Large","Mid","Large","Mid","Startup","Startup","Large","Large","Large","Large","Large","Startup","Startup","Large","Startup","Large","Mid","Startup","Mid","Mid","Startup","Large","Startup","Large","Large","Mid","Large","Mid","Mid","Startup","Large","Large","Mid","Startup","Startup","Mid","Large","Startup","Mid","Mid","Mid","Startup","Startup","Startup","Large","Large","Large","Mid","Mid","Mid","Startup","Large","Startup","Large","Large","Large","Large","Mid","Large","Mid","Mid","Startup","Startup","Mid","Large","Mid","Large","Mid","Large","Startup","Large","Startup","Large","Large","Large","Mid","Large","Startup","Startup","Startup","Startup","Startup","Large","Startup","Mid","Startup","Large","Large","Startup","Large","Large","Large","Startup","Startup","Mid","Large","Startup","Mid","Mid","Mid","Mid","Large","Large","Large","Mid","Startup","Startup","Mid","Startup","Large","Startup","Mid","Startup","Startup","Large","Mid","Large","Large","Large","Mid","Mid","Startup","Startup","Startup","Startup","Mid","Large","Large","Mid","Startup","Mid","Startup","Mid","Mid","Startup","Large","Large","Mid","Startup","Large","Startup","Startup","Large","Large","Mid","Large","Large","Startup","Large","Large","Mid","Mid","Mid","Mid","Mid","Mid","Large","Mid","Mid","Startup","Large","Startup","Mid","Startup","Large","Startup","Large","Mid","Startup","Mid","Mid","Mid","Startup","Startup","Startup","Mid ...
# <div>                            <div id="29e1137e-9114-4f97-9891-4c2cb85183a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("29e1137e-9114-4f97-9891-4c2cb85183a6")) {                    Plotly.newPlot(                        "29e1137e-9114-4f97-9891-4c2cb85183a6",                        [{"alignmentgroup":"True","hovertemplate":"employment_type=%{x}\u003cbr\u003eavg_salary=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Contract","marker":{"color":"#023047"},"name":"Contract","notched":false,"offsetgroup":"Contract","orientation":"v","showlegend":true,"x":["Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Contract","Co ...

# %% [markdown]
# ### 5.3 Location & Geography

# %%
# 1. Global AI Hubs (Map)
if 'country' in df.columns:
    plot_choropleth_map(df, 'country', 'Global AI Jobs Distribution').show()

# 2. Top Countries by Job Count
plot_bar_chart(df, 'country', 'Top 10 Countries by Job Count', top_n=10).show()

# 3. Location Impact on Salary (Top 10 Countries)
top_countries = df['country'].value_counts().head(10).index
df_top_countries = df[df['country'].isin(top_countries)]
plot_box_comparison(df_top_countries, 'country', 'avg_salary', 'Salary Distribution in Top 10 Countries').show()

# 4. Industry Concentration by Country (Heatmap)
top_industries = df['industry'].value_counts().head(10).index
df_filtered_loc = df[df['country'].isin(top_countries) & df['industry'].isin(top_industries)]
plot_heatmap(df_filtered_loc, 'industry', 'country', 'Industry Concentration by Country').show()
# Out:
# <div>                            <div id="6e792a6a-3142-42f1-aa73-8c9048feb976" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e792a6a-3142-42f1-aa73-8c9048feb976")) {                    Plotly.newPlot(                        "6e792a6a-3142-42f1-aa73-8c9048feb976",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry=%{location}\u003cbr\u003ecount=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Papua New Guinea","Croatia","Barbados","Bhutan","Fiji","Iraq","Jordan","Equatorial Guinea","Jamaica","Uzbekistan","Madagascar","Guatemala","Palau","Bolivia","Seychelles","Bahamas","Luxembourg","Samoa","India","Switzerland","Niger","Kyrgyzstan","Djibouti","Mexico","Saint Vincent and the Grenadines","Dominican Republic","Timor-Leste","Sweden","Kiribati","Mongolia","Germany","South Africa","Namibia","Nicaragua","Myanmar","Zambia","Cuba","Angola","Romania","Gabon","Montenegro","Tonga","Tuvalu","Liberia","Honduras","Yemen","Colombia","Malawi","Senegal","Kenya","Bahrain","Liechtenstein","Monaco","Poland","Belgium","Uganda","Czech Republic","Bulgaria","Belarus","Afghanistan","North Korea","Ethiopia","Uruguay","Lebanon","Brazil","Finland","New Zealand","Taiwan","Tunisia","Mauritania","Botswana","Sierra Leone","Marshall Islands","Vanuatu","Maldives","United Kingdom","Qatar","Andorra","France","Albania","Eswatini","Dominica","Netherlands","Saudi Arabia","Comoros","Burkina Faso","Nigeria","Turkey","Philippines","Chile","Burundi","Moldova","Norway","Guinea","Palestine","Italy","Antigua and Barbuda","Gambia","Haiti","Rwanda","Cape Verde","Georgia","Panama","United States","Paraguay","Trinidad and Tobago","Venezuela","Eritrea","Slovakia","Greece","Vatican City","Australia","Belize","North Macedonia","Azerbaijan","Micronesia","Singapore","China","Ireland","Nepal","Austria","Nauru","Sri Lanka","Argentina","Democratic Republic of the Congo","Togo","Cyprus","Vietnam","Guinea-Bissau","Morocco","San Marino","Kuwait","Ivory Coast","Algeria","Lithuania","Russia","South Korea","Saint Kitts and Nevis","Canada","Solomon Islands","Saint Lucia","Bosnia and Herzegovina","Ukraine","Israel","Grenada","Iran","Mauritius","Mozambique","Costa Rica","Central African Republic","Kazakhstan","Sao Tome and Principe","Benin","Spain","Syria","Thailand","Chad","Armenia","Hungary","Tanzania","United Arab Emirates","Bangladesh","Tajikistan","Congo","Indonesia","Denmark","Laos","Pakistan","Portugal","Zimbabwe","Serbia","Oman","Malaysia","Mali","Iceland","Malta","Libya","Japan","Guyana","Turkmenistan","Brunei","Cambodia","El Salvador","Egypt","Lesotho","Latvia","Cameroon","Suriname","Somalia","Slovenia","Sudan","Peru","Ghana","Estonia","Ecuador"],"locationmode":"country names","locations":["Papua New Guinea","Croatia","Barbados","Bhutan","Fiji","Iraq","Jordan","Equatorial Guinea","Jamaica","Uzbekistan","Madagascar","Guatemala","Palau","Bolivia","Seychelles","Bahamas","Luxembourg","Samoa","India","Switzerland","Niger","Kyrgyzstan","Djibouti","Mexico","Saint Vincent and the Grenadines","Dominican Republic","Timor-Leste","Sweden","Kiribati","Mongolia","Germany","South Africa","Namibia","Nicaragua","Myanmar","Zambia","Cuba","Angola","Romania","Gabon","Montenegro","Tonga","Tuvalu","Liberia","Honduras","Yemen","Colombia","Malawi","Senegal","Kenya","Bahrain","Liechtenstein","Monaco","Poland","Belgium","Uganda","Czech Republic","Bulgaria","Belarus","Afghanistan","North Korea","Ethiopia","Uruguay","Lebanon","Brazil","Finland","New Zealand","Taiwan","Tunisia","Mauritania","Botswana","Sierra Leone","Marshall Islands","Vanuatu","Maldives","United Kingdom","Qatar","Andorra","France","Albania","Eswatini","Dominica","Netherlands","Saudi Arabia", ...
# <div>                            <div id="5f1aeeed-43c4-4bd4-9a10-3448c905d48b" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f1aeeed-43c4-4bd4-9a10-3448c905d48b")) {                    Plotly.newPlot(                        "5f1aeeed-43c4-4bd4-9a10-3448c905d48b",                        [{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003ecount=%{y}\u003cbr\u003epercent=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#023047","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[11.0,10.4,10.4,10.4,10.4,9.8,9.8,9.2,9.2,9.2],"textposition":"outside","x":["Papua New Guinea","Croatia","Barbados","Bhutan","Fiji","Iraq","Jordan","Equatorial Guinea","Jamaica","Uzbekistan"],"xaxis":"x","y":[19,18,18,18,18,17,17,16,16,16],"yaxis":"y","type":"bar","texttemplate":"%{text:.1f}%"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoord ...
# <div>                            <div id="42790814-8d7c-4ffa-a47c-29665438d52a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("42790814-8d7c-4ffa-a47c-29665438d52a")) {                    Plotly.newPlot(                        "42790814-8d7c-4ffa-a47c-29665438d52a",                        [{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003eavg_salary=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#023047"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Equatorial Guinea","Fiji","Barbados","Barbados","Equatorial Guinea","Uzbekistan","Croatia","Iraq","Bhutan","Papua New Guinea","Jamaica","Croatia","Jordan","Papua New Guinea","Bhutan","Jordan","Fiji","Equatorial Guinea","Jordan","Bhutan","Croatia","Barbados","Iraq","Jamaica","Jamaica","Jordan","Croatia","Papua New Guinea","Barbados","Croatia","Iraq","Barbados","Croatia","Barbados","Uzbekistan","Jordan","Iraq","Equatorial Guinea","Jordan","Fiji","Iraq","Jamaica","Iraq","Papua New Guinea","Barbados","Uzbekistan","Jamaica","Iraq","Barbados","Jamaica","Bhutan","Jamaica","Barbados","Equatorial Guinea","Jordan","Uzbekistan","Uzbekistan","Bhutan","Bhutan","Fiji","Fiji","Fiji","Papua New Guinea","Papua New Guinea","Fiji","Iraq","Jordan","Uzbekistan","Jordan","Bhutan","Jordan","Bhutan","Iraq","Barbados","Uzbekistan","Papua New Guinea","Equatorial Guinea","Croatia","Jordan","Jordan","Papua New Guinea","Iraq","Iraq","Iraq","Bhutan","Croatia","Iraq","Bhutan","Bhutan","Jordan","Iraq","Uzbekistan","Equatorial Guinea","Uzbekistan","Jamaica","Fiji","Barbados","Papua New Guinea","Equatorial Guinea","Papua New Guinea","Equatorial Guinea","Fiji","Jamaica","Fiji","Papua New Guinea","Equatorial Guinea","Papua New Guinea","Equatorial Guinea","Papua New Guinea","Equatorial Guinea","Bhutan","Uzbekistan","Fiji","Fiji","Barbados","Equatorial Guinea","Fiji","Papua New Guinea","Fiji","Fiji","Uzbekistan","Barbados","Equatorial Guinea","Bhutan","Jamaica","Jordan","Croatia","Fiji","Uzbekistan","Jamaica","Bhutan","Jordan","Equatorial Guinea","Iraq","Jordan","Uzbekistan","Jamaica","Barbados","Croatia","Papua New Guinea","Bhutan","Jamaica","Bhutan","Iraq","Papua New Guinea","Bhutan","Papua New Guinea","Barbados","Iraq","Croatia","Uzbekistan","Papua New Guinea","Croatia","Jamaica","Papua New Guinea","Croatia","Bhutan","Fiji","Uzbekistan","Barbados","Equatorial Guinea","Croatia","Croatia","Uzbekistan","Croatia","Jamaica","Jamaica","Barbados","Jordan","Fiji","Croatia","Croatia","Barbados"],"x0":" ","xaxis":"x","y":[165489.5,173291.5,117249.5,103727.5,165480.5,105000.5,149552.0,176787.5,117190.0,177701.5,107123.5,69148.5,114860.5,174978.0,75276.0,128946.0,169983.5,192467.0,91205.5,100867.5,138981.5,170571.5,71705.0,146010.0,117808.0,94120.5,93142.5,85976.5,67737.0,101909.0,167789.0,161337.0,115892.0,121822.5,59575.0,145152.5,63829.5,85317.5,57532.5,120392.0,166076.0,154278.5,87312.5,96035.5,170093.5,101978.5,107305.5,83187.0,145050.0,172673.0,89244.5,99580.5,81549.5,182196.5,89075.5,104723.5,98471.5,101626.0,172014.5,67997.0,65242.0,168659.0,91813.0,80668.5,181054.0,128309.0,176201.5,130050.0,88778.5,153416.0,131741.5,86563.0,94325.0,133842.5,162662.0,87395.5,173848.0,101987.0,173148.0,172099.0,139992.0,185232.5,109410.0,79640.0,107609.5,119824.5,125912.0,115231.0,152169.5,166850.0,80571.5,184972.0,168046.0,131966.5,89387.5,186577.0,54206.5,106442.0,64705.0,190330.5,94029.5,155008.5,180726.5,117271.0,100350.0,109805.5,182573.5,108761.5,106784.5,107572.5,132727.5,123036.0,145062.0,136665.5,144666.5,173635.5,146054.5,160367.0,128952.0,91022.5,166692.5,64069.0,194145.5,87623.5,98621.5,166374.0,119020.5,124579.0,58720.0,179293.5,76478.5,61594.5,189270.0,152158.5,49431.0,104712.5,177868.5,117816.5 ...
# <div>                            <div id="65675fad-1a4e-4651-8a13-62bf51cd2e8c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("65675fad-1a4e-4651-8a13-62bf51cd2e8c")) {                    Plotly.newPlot(                        "65675fad-1a4e-4651-8a13-62bf51cd2e8c",                        [{"coloraxis":"coloraxis","name":"0","x":["Automotive","E-commerce","Education","Finance","Healthcare","Retail","Tech"],"y":["Barbados","Bhutan","Croatia","Equatorial Guinea","Fiji","Iraq","Jamaica","Jordan","Papua New Guinea","Uzbekistan"],"z":[[3,1,2,3,5,1,3],[4,3,3,2,0,2,4],[4,2,1,3,3,1,4],[0,1,2,4,4,2,3],[3,2,3,0,6,2,2],[2,3,3,2,0,6,1],[4,4,0,1,2,1,4],[5,3,3,3,0,1,2],[1,4,5,3,1,4,1],[1,5,2,3,2,1,2]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"industry: %{x}\u003cbr\u003ecountry: %{y}\u003cbr\u003eCount: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{ ...

# %% [markdown]
# ### 5.4 Time Series Analysis

# %%
# 1. Jobs per Time Unit
plot_time_trend(df, 'quarter', None, 'Hiring Volume per Quarter', 'count').show()
plot_time_trend(df, 'month', None, 'Hiring Volume per Month', 'count').show()
plot_time_trend(df, 'day_name', None, 'Hiring Volume per Day', 'count').show()

# 2. Salary Trends
plot_time_trend(df, 'quarter', 'avg_salary', 'Average Salary per Quarter', 'mean').show()
plot_time_trend(df, 'month', 'avg_salary', 'Average Salary per Month', 'mean').show()
# Out:
# <div>                            <div id="38155b5e-c4a0-4fe7-b758-f78db9707393" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38155b5e-c4a0-4fe7-b758-f78db9707393")) {                    Plotly.newPlot(                        "38155b5e-c4a0-4fe7-b758-f78db9707393",                        [{"alignmentgroup":"True","hovertemplate":"quarter=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#023047","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2s}","x":["Q1","Q3","Q4","Q2"],"xaxis":"x","y":[529,521,503,447],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorba ...
# <div>                            <div id="8575f680-6334-426e-994f-a57948979577" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8575f680-6334-426e-994f-a57948979577")) {                    Plotly.newPlot(                        "8575f680-6334-426e-994f-a57948979577",                        [{"alignmentgroup":"True","hovertemplate":"month=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#023047","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2s}","x":["August","March","September","January","October","December","February","April","July","November","May","June"],"xaxis":"x","y":[186,183,182,182,180,172,164,158,153,151,149,140],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pi ...
# <div>                            <div id="e5136883-0b42-4dde-8cf5-45c148c0fda0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e5136883-0b42-4dde-8cf5-45c148c0fda0")) {                    Plotly.newPlot(                        "e5136883-0b42-4dde-8cf5-45c148c0fda0",                        [{"alignmentgroup":"True","hovertemplate":"day_name=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#023047","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2s}","x":["Thursday","Sunday","Friday","Tuesday","Monday","Saturday","Wednesday"],"xaxis":"x","y":[315,299,296,291,281,264,254],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"lin ...
# <div>                            <div id="9abf66e1-1055-4df9-8f0f-e8e3e78c7443" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9abf66e1-1055-4df9-8f0f-e8e3e78c7443")) {                    Plotly.newPlot(                        "9abf66e1-1055-4df9-8f0f-e8e3e78c7443",                        [{"alignmentgroup":"True","hovertemplate":"quarter=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#023047","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2s}","x":["Q3","Q4","Q2","Q1"],"xaxis":"x","y":[123602.00383877159,123593.07157057655,123388.6029082774,121666.04631379963],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{" ...
# <div>                            <div id="2e570d17-6b1f-42e7-b56f-9d21afa08516" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e570d17-6b1f-42e7-b56f-9d21afa08516")) {                    Plotly.newPlot(                        "2e570d17-6b1f-42e7-b56f-9d21afa08516",                        [{"alignmentgroup":"True","hovertemplate":"month=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#023047","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2s}","x":["April","August","May","December","September","November","January","October","February","March","July","June"],"xaxis":"x","y":[127483.43037974683,126222.29032258065,125271.46979865772,125254.94767441861,124167.73076923077,123998.22516556291,122780.97252747252,121665.17777777778,121432.5762195122,120766.44262295082,119743.60130718954,116763.3892857143],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}}," ...

# %% [markdown]
# ### 5.5 Skills Analysis

# %%
# %%
# Define key skills to analyze (ensure they exist in columns)
target_skills = ['AWS', 'Azure', 'BigQuery', 'C++', 'CUDA', 'Excel', 'FastAPI', 'Flask', 'GCP', 
                 'Hugging Face', 'KDB+', 'Keras', 'LangChain', 'MLflow', 'NumPy', 'Pandas', 
                 'Power BI', 'PyTorch', 'Python', 'R', 'Reinforcement Learning', 'SQL', 
                 'Scikit-learn', 'TensorFlow']

existing_skills = [col for col in target_skills if col in df.columns]

# 16. Standard Tech Stack (Top Skills)
skills_sum = df[existing_skills].sum().sort_values(ascending=False).reset_index()
skills_sum.columns = ['Skill', 'Count']
skills_sum['percent'] = (skills_sum['Count'] / len(df) * 100).round(1)

fig_stack = px.bar(skills_sum.head(20), x='Count', y='Skill', orientation='h', 
                   title='Top 20 In-Demand Skills', text='percent', color='Count')
fig_stack.update_traces(texttemplate='%{text:.1f}%', textposition='outside')
fig_stack.update_layout(yaxis={'categoryorder':'total ascending'}, showlegend=False, height=600)
fig_stack.show()

# 17. Skill Definition per Role (Heatmap)
job_skill_matrix = df.groupby('job_title')[existing_skills].sum()
fig_roles = px.imshow(job_skill_matrix, title='Skill Frequency per Job Title', aspect='auto',
                      labels=dict(x="Skill", y="Job Title", color="Count"))
fig_roles.show()

# 18. Skill Demand by Company Size
size_skill_matrix = df.groupby('company_size')[existing_skills].sum()
fig_startups = px.imshow(size_skill_matrix, title='Skill Demand by Company Size', aspect='auto',
                         labels=dict(x="Skill", y="Company Size", color="Count"))
fig_startups.show()

# 19. Tech Stack Complexity
df['skills_count'] = df[existing_skills].sum(axis=1)
plot_distribution(df, 'skills_count', 'Tech Stack Complexity (Skills per Job)').show()
# Out:
# <div>                            <div id="9920ee3d-3fd6-4b1b-bb02-3ea24c3e011d" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9920ee3d-3fd6-4b1b-bb02-3ea24c3e011d")) {                    Plotly.newPlot(                        "9920ee3d-3fd6-4b1b-bb02-3ea24c3e011d",                        [{"alignmentgroup":"True","hovertemplate":"Count=%{marker.color}\u003cbr\u003eSkill=%{y}\u003cbr\u003epercent=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[825,812,811,810,796,786,499,494,432,427,416,414,413,408,408,406,404,404,404,402],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"text":[41.2,40.6,40.6,40.5,39.8,39.3,25.0,24.7,21.6,21.3,20.8,20.7,20.6,20.4,20.4,20.3,20.2,20.2,20.2,20.1],"textposition":"outside","x":[825,812,811,810,796,786,499,494,432,427,416,414,413,408,408,406,404,404,404,402],"xaxis":"x","y":["TensorFlow","FastAPI","MLflow","LangChain","Scikit-learn","PyTorch","KDB+","BigQuery","Excel","Pandas","NumPy","Reinforcement Learning","Azure","SQL","Hugging Face","Keras","AWS","Power BI","GCP","Python"],"yaxis":"y","type":"bar","texttemplate":"%{text:.1f}%"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.666666666666 ...
# <div>                            <div id="6f877d73-a87d-4b67-bc3a-30c04bb68827" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6f877d73-a87d-4b67-bc3a-30c04bb68827")) {                    Plotly.newPlot(                        "6f877d73-a87d-4b67-bc3a-30c04bb68827",                        [{"coloraxis":"coloraxis","name":"0","x":["AWS","Azure","BigQuery","C++","CUDA","Excel","FastAPI","Flask","GCP","Hugging Face","KDB+","Keras","LangChain","MLflow","NumPy","Pandas","Power BI","PyTorch","Python","R","Reinforcement Learning","SQL","Scikit-learn","TensorFlow"],"y":["AI Product Manager","AI Researcher","Computer Vision Engineer","Data Analyst","Data Scientist","ML Engineer","NLP Engineer","Quant Researcher"],"z":[[46,52,65,58,54,51,110,52,52,49,71,55,108,118,66,49,47,96,51,57,57,60,112,101],[54,50,51,39,49,53,99,47,49,53,45,46,110,92,57,60,58,89,52,46,39,40,85,89],[41,47,50,44,47,51,85,48,40,52,67,46,87,94,45,57,41,97,43,50,37,48,96,113],[54,41,78,46,52,69,101,46,60,51,71,57,103,116,53,60,61,116,45,45,67,56,106,117],[56,53,65,56,43,51,98,55,48,44,61,42,93,94,45,59,44,82,49,43,63,44,102,94],[56,54,64,45,46,52,95,50,42,56,55,45,111,96,44,35,39,94,54,50,47,56,103,105],[54,57,62,65,53,47,126,49,56,46,61,55,96,116,61,61,60,109,55,52,49,47,85,98],[43,59,59,37,53,58,98,51,57,57,68,60,102,85,45,46,54,103,53,50,55,57,107,108]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"Skill: %{x}\u003cbr\u003eJob Title: %{y}\u003cbr\u003eCount: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88888888 ...
# <div>                            <div id="cc534e57-a42d-4391-b574-09344d2f64ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc534e57-a42d-4391-b574-09344d2f64ac")) {                    Plotly.newPlot(                        "cc534e57-a42d-4391-b574-09344d2f64ac",                        [{"coloraxis":"coloraxis","name":"0","x":["AWS","Azure","BigQuery","C++","CUDA","Excel","FastAPI","Flask","GCP","Hugging Face","KDB+","Keras","LangChain","MLflow","NumPy","Pandas","Power BI","PyTorch","Python","R","Reinforcement Learning","SQL","Scikit-learn","TensorFlow"],"y":["Large","Mid","Startup"],"z":[[121,132,146,133,127,121,255,120,145,136,156,142,271,265,146,142,132,264,128,136,136,134,255,288],[141,156,179,127,135,157,293,142,123,143,169,129,238,276,144,138,137,261,138,129,124,127,259,276],[142,125,169,130,135,154,264,136,136,129,174,135,301,270,126,147,135,261,136,128,154,147,282,261]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"Skill: %{x}\u003cbr\u003eCompany Size: %{y}\u003cbr\u003eCount: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d" ...
# <div>                            <div id="7ed25b5c-74ae-4279-8c34-e56d20c56899" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7ed25b5c-74ae-4279-8c34-e56d20c56899")) {                    Plotly.newPlot(                        "7ed25b5c-74ae-4279-8c34-e56d20c56899",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"skills_count=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#023047","pattern":{"shape":""}},"name":"","nbinsx":40,"offsetgroup":"","orientation":"v","showlegend":false,"x":[8,7,8,9,6,7,6,4,6,4,6,7,5,8,4,4,4,6,9,5,9,7,7,6,4,7,8,5,8,4,5,7,7,6,5,6,6,4,5,8,8,5,8,7,6,6,5,6,7,9,6,9,7,7,8,9,6,8,7,7,4,7,5,4,7,8,5,7,7,4,5,6,6,5,6,6,3,7,4,5,7,9,5,6,7,8,5,4,7,6,8,5,6,7,7,6,7,7,7,5,5,8,5,4,7,8,5,9,5,5,6,7,5,6,8,5,8,4,8,9,5,7,7,7,4,4,6,7,7,5,7,6,6,6,8,6,7,6,9,7,8,7,7,6,6,7,5,5,4,5,7,4,4,6,7,6,8,9,9,8,7,5,7,6,5,6,5,6,8,4,6,7,7,6,6,7,8,7,7,7,6,5,7,6,5,6,5,7,6,6,7,5,6,5,4,5,7,4,7,4,6,7,8,6,7,4,6,4,8,8,7,5,6,5,7,8,7,6,7,7,9,8,7,7,6,7,6,7,6,6,6,6,6,6,3,7,8,5,8,7,8,7,9,4,6,6,4,6,6,6,7,7,4,5,5,7,5,8,7,7,6,4,9,7,7,7,6,7,4,6,6,3,5,5,7,6,4,6,6,5,6,4,8,5,6,6,5,6,6,6,7,7,5,6,5,7,8,5,7,6,8,9,6,7,7,6,8,6,8,8,7,6,8,6,7,5,7,7,7,6,7,6,7,6,6,6,5,5,6,5,8,4,6,7,7,7,8,8,5,7,5,6,5,5,5,8,5,6,6,6,5,6,6,7,7,8,4,6,7,4,5,4,8,6,8,5,5,5,7,6,7,6,5,8,4,7,5,4,5,7,6,7,6,4,7,7,7,7,5,8,4,4,6,7,6,6,5,4,5,9,5,5,5,4,4,7,5,6,5,7,6,7,5,5,5,5,6,7,4,7,5,5,6,4,7,4,8,6,8,5,7,5,9,6,6,8,4,6,9,4,5,9,4,5,8,6,6,5,8,5,6,5,6,8,5,6,7,5,6,8,8,5,4,7,6,5,3,6,5,5,7,4,6,6,6,4,6,7,5,5,6,7,7,7,9,8,6,6,5,5,5,5,8,8,6,4,7,6,7,7,4,8,7,6,4,8,3,4,8,6,7,7,6,7,8,6,6,4,8,5,5,6,6,5,7,6,6,5,8,8,5,6,6,6,5,7,5,4,5,5,4,7,7,6,6,4,6,4,7,4,8,3,5,6,3,6,5,9,8,6,7,6,4,6,7,6,7,6,7,8,5,7,7,5,5,5,8,4,5,7,5,6,7,4,5,6,5,7,8,6,8,8,9,7,5,7,7,8,4,7,7,6,8,8,7,5,7,9,4,6,5,6,4,6,6,5,5,5,7,5,7,7,6,9,6,8,8,7,6,7,7,7,7,9,9,4,8,7,5,3,6,8,5,7,7,5,5,7,5,6,6,6,5,8,6,4,8,5,9,5,7,7,6,4,7,5,6,5,7,6,7,7,9,8,7,8,6,7,6,7,7,5,3,6,6,4,6,6,4,5,8,7,7,7,6,4,6,4,8,6,7,6,6,8,8,4,5,6,4,6,7,6,4,6,6,6,7,8,7,7,7,7,8,6,4,8,8,5,6,6,5,8,5,8,6,8,5,6,5,9,6,7,6,9,6,4,8,8,7,6,8,7,6,6,6,5,7,6,5,3,5,8,6,6,7,8,5,5,5,5,6,6,6,5,7,5,7,6,5,6,6,4,8,6,8,7,5,8,4,8,6,5,9,8,8,7,5,6,4,4,7,5,6,6,6,4,7,7,7,4,5,7,6,6,8,7,4,7,6,8,5,4,6,4,8,7,6,5,5,7,6,7,6,4,8,5,4,7,5,7,5,7,8,7,8,9,5,8,6,6,4,4,6,5,8,6,6,7,9,8,5,8,7,8,7,5,6,6,5,6,6,8,6,5,6,5,6,4,7,5,5,5,6,6,9,4,6,8,5,4,6,6,5,7,7,4,8,5,6,7,6,6,8,7,8,5,4,4,7,8,5,4,5,6,8,3,5,5,9,4,8,7,6,6,6,4,7,8,6,7,8,7,4,4,6,6,5,7,4,9,7,7,7,5,9,6,6,8,7,7,6,6,6,4,9,7,5,4,7,5,4,7,8,6,7,8,9,8,6,7,8,8,7,6,4,7,6,3,6,5,6,5,6,9,5,5,7,6,6,8,7,7,9,9,6,6,7,5,8,8,8,4,8,6,7,4,5,7,7,6,4,8,5,6,6,6,5,6,6,6,6,4,6,7,7,7,5,4,6,5,5,8,5,5,8,7,3,7,7,4,7,6,6,7,6,7,8,6,6,7,7,5,5,5,8,8,5,7,8,7,6,5,7,8,9,4,6,8,7,5,7,8,7,6,4,8,7,7,6,6,8,8,9,8,6,9,5,7,8,5,6,7,5,6,7,7,7,8,6,6,8,6,5,5,4,7,6,6,9,6,8,4,4,6,5,5,7,6,6,7,5,7,8,6,6,5,4,4,6,8,5,5,5,6,8,8,4,8,6,6,7,8,5,6,8,5,8,7,7,5,8,4,7,6,7,4,4,6,9,6,7,6,6,8,7,4,6,8,5,7,4,5,7,8,6,8,8,6,7,7,6,8,7,5,7,5,9,6,7,7,6,6,5,7,6,9,5,6,7,8,4,6,5,7,4,6,6,6,8,8,8,6,8,4,6,4,6,5,9,7,8,5,9,8,4,7,6,4,7,7,7,6,6,5,8,7,5,8,4,7,7,7,3,8,7,5,7,7,5,7,7,6,9,7,3,4,4,7,5,7,4,6,7,5,9,7,3,7,7,6,8,5,6,7,9,7,8,6,4,4,5,6,5,7,4,7,6,3,5,6,6,8,7,3,5,4,7,5,5,7,7,7,6,8,8,7,7,4,7,7,7,8,8,6,5,7,6,8,3,4,4,6,7,4,4,6,6,7,6,8,6,4,4,6,8,5,5,6,7,6,7,5,8,5,7,8,6,7,5,6,5,6,4,7,4,7,7,6,7,6,7,5,5,3,5,5,5,6,6,7,5,8,4,4,7,6,6,7,4,5,7,5,7,6,8,6,4,7,5,5,5,6,5,7,8,4,5,7,6,7,9,4,4,5,6,6,7,7,4,6,7,6,5,7,3,7,7,9,4,7,8,9,7,8,7,8,6,4,5,8,6,6,6,8,6,6,8,5,4,5,3,7,6,7,4,6,6,8,6,7,4,3,5,5,7,8,5,8,6,5,5,4,7,7,7,4,7,5,8,5,7,6,7,6,7,6,6,4,4,5,4,6,5,5,7,6,8,7,7,7,6,7,7,5,7,8,4,5,6,7,4,8,7,7,4,8,6,8,6,9,6,7,5,7,6,7,6,9,8,7,9,7,8,7,3,5,7,4,8,9,6,6,6,5,4,5,5,6,8,5,5,8,5,6,5,4,8,6,5,7,7,6,9,6,8,6,6,7,7,6,4,6,8,7,7,4,8,8,6,7,4,5,5,5,7,4,7,6,5,7,3,4,7,7,6,4,6,7,6,4 ...

# %% [markdown]
# ## 6. Conclusion

# %% [markdown]
# Based on our comprehensive analysis of the AI Job Market dataset, we have derived the following key insights that define the current landscape:
#
# ### 1. A Balanced Market Ecosystem
# Contrary to markets dominated by a few tech giants, our analysis reveals a **highly balanced ecosystem**.
# * **Hiring Volume:** There is no massive gap between top hiring companies; the demand is evenly distributed.
# * **Industry & Company Size:** Similarly, job opportunities are spread consistently across various industries and company sizes (Startups vs. Large firms), indicating a healthy and diverse market.
#
# ### 2. The "Entry-Level" Boom
# The data highlights a **strong preference for Entry-level talent** over Senior roles in terms of volume. This suggests the AI sector is still in an expansion phase, eager to onboard new talent to build foundational teams.
#
# ### 3. Location is the Key Differentiator
# While industry and company size show uniform distributions, **Geography (Location)** emerges as the most significant factor influencing **Salary**. Where you work matters more than who you work for when it comes to compensation variance.
#
# ### 4. Strategic Timing (Seasonality)
# For job seekers, timing plays a crucial role:
# * **Best Quarter:** **Q1 (First Quarter)** is the most active hiring season, likely due to new fiscal year budgets.
# * **Peak Month:** Surprisingly, **August** stands out as the single month with the highest hiring activity, marking a strategic window for applications.
#
# ### 5. The Must-Have Tech Stack
# To remain competitive, candidates must master the core tools that appear in almost every job description. The top two non-negotiable skills are:
# 1. **[Tensorflow]**
# 2. **[FastAPI]**
#
# ---
# **Final Recommendation:**
# Job seekers should focus on mastering the core tech stack and applying aggressively during **Q1 and late summer (August)**. Since the market is friendly to entry-level roles, building a strong portfolio is key to seizing these abundant opportunities.
